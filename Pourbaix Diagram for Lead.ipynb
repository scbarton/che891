# %% [markdown]
# # Pourbaix Diagram for Lead

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You may also take advantage of [Appendix A of the text](http://www.egr.msu.edu/~scb/downloads/Fuller_Appendix_A.pdf).

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
